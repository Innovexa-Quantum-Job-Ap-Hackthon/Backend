# %%
from qcompile_magic import *
# Import the DEBUG version
# from notebooks.jupyter_magic_integration_debug import *
# Out:
# <div style="border: 2px solid #28a745; padding: 15px; border-radius: 5px; background-color: #f8f9fa; margin: 10px 0;">
#     <h3 style="color: #28a745; margin-top: 0;">✅ Module imported Successfully</h3>
# </div>

# %%
# %%qcompile
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg q[3];
# creg c[3];
# h q[0];
# cx q[0],q[1];
# cx q[1],q[2];
# measure q[0] -> c[0];
# measure q[1] -> c[1];
# measure q[2] -> c[1];
# Out:
# 🔬 Compilation Results
#     <style>
#     table {
#         border-collapse: collapse;
#         width: 100%;
#         font-family: Arial, sans-serif;
#     }
#     th, td {
#         border: 1px solid #ddd;
#         padding: 8px;
#         text-align: center;
#     }
#     th {
#         background-color: #4CAF50;
#         color: white;
#     }
#     tr:nth-child(even) {background-color: #f2f2f2;}
#     tr:hover {background-color: #ddd;}
#     .submit-btn {
#         background-color: #007bff;
#         color: white;
#         border: none;
#         padding: 5px 10px;
#         cursor: pointer;
#         border-radius: 3px;
#     }
#     .submit-btn:hover {
#         background-color: #0056b3;
#     }
#     .submit-btn:disabled {
#         background-color: #6c757d;
#         cursor: not-allowed;
#     }
#     .job-id {
#         color: #28a745;
#         font-weight: bold;
#     }
#     </style>
#     <h3>Compilation Results Summary</h3>
#     <table id="compilation-table">
#         <thead>
#             <tr>
#                 <th>Device</th>
#                 <th>Status</th>
#                 <th>Required Qubits</th>
#                 <th>Available Qubits</th>
#                 <th>Additional SWAPs</th>
#                 <th>Circuit Depth</th>
#                 <th>Est. Fidelity</th>
#                 <th>Compilation Time (s)</th>
#                 <th>Cost Estimation (USD) </th>
#                 <th>Action</th>
#             </tr>
#         </thead>
#         <tbody>
#
#             <tr>
#                 <td>ibm_torino</td>
#                 <td>Executable</td>
#                 <td>3</td>
#                 <td>133</td>
#                 <td>0</td>
#                 <td>10</td>
#                 <td>89.55%</td>
#                 <td>1.074</td>
#                 <td>0.011462</td>
#                 <td id="action-ibm_torino"><button class="submit-btn" onclick="submitJob('ibm_torino', 'OPENQASM 2.0;\ninclude &quot;qelib1.inc&quot;;\nqreg q[3];\ncreg c[3];\nh q[0];\ncx q[0],q[1];\ncx q[1],q[2];\nmeasure q[0] -&gt; c[0];\nmeasure q[1] -&gt; c[1];\nmeasure q[2] -&gt; c[1];', 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ0ZWphOTAyMjZAZ21haWwuY29tIiwiZXhwIjozNTU4OTg3NzQ0fQ.NvblbrGHk7OnUubP2yxvfA84GAWId8UWDyhUQ9WlQyU')">Submit to IBM</button></td>
#             </tr>
#
#             <tr>
#                 <td>ibm_brisbane</td>
#                 <td>Executable</td>
#                 <td>3</td>
#                 <td>127</td>
#                 <td>0</td>
#                 <td>13</td>
#                 <td>88.46%</td>
#                 <td>0.941</td>
#                 <td>0.009453</td>
#                 <td id="action-ibm_brisbane"><button class="submit-btn" onclick="submitJob('ibm_brisbane', 'OPENQASM 2.0;\ninclude &quot;qelib1.inc&quot;;\nqreg q[3];\ncreg c[3];\nh q[0];\ncx q[0],q[1];\ncx q[1],q[2];\nmeasure q[0] -&gt; c[0];\nmeasure q[1] -&gt; c[1];\nmeasure q[2] -&gt; c[1];', 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ0ZWphOTAyMjZAZ21haWwuY29tIiwiZXhwIjozNTU4OTg3NzQ0fQ.NvblbrGHk7OnUubP2yxvfA84GAWId8UWDyhUQ9WlQyU')">Submit to IBM</button></td>
#             </tr>
#
#         </tbody>
#     </table>
#     <script>
#     async function submitJob(deviceName, circuitCode, token) {
#         const button = document.querySelector(`#action-${deviceName} .submit-btn`);
#         if (button) {
#             button.disabled = true;
#             button.textContent = 'Submitting...';
#         }
#
#         try {
#             const response = await fetch('http://localhost:8000/api/submit-circuit-to-ibm', {
#                 method: 'POST',
#                 headers: {
#                     'Content-Type': 'application/json',
#                     'Authorization': `Bearer ${token}`
#                 },
#                 body: JSON.stringify({
#                     circuit_code: circuitCode,
#                     device_name: deviceName,
#                     shots: 1024
#                 })
#             });
#
#             if (response.ok) {
#                 const data = await response.json();
#                 const actionCell = document.getElementById(`action-${deviceName}`);
#                 actionCell.innerHTML = `<span class="job-id">Job ID: ${data.job_id}</span>`;
#                 console.log('Job submitted successfully:', data);
#             } else {
#                 const errorData = await response.json();
#                 throw new Error(errorData.detail || 'Submission failed');
#             }
#         } catch (error) {
#             console.error('Error submitting job:', error);
#             const actionCell = document.getElementById(`action-${deviceName}`);
#             actionCell.innerHTML = `<span style="color: red;">Error: ${error.message}</span>`;
#             if (button) {
#                 button.disabled = false;
#                 button.textContent = 'Submit to IBM';
#             }
#         }
#     }
#     </script>
# Status: success
# Message: Compilation and device integration analysis completed
# Step: Step 4 - Compilation Results
# ===============================

# %%
# Install Aer if missing
# !pip install -q qiskit qiskit-aer

# Import needed modules
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

# Build a simple 2-qubit Bell state circuit
qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure_all()

# Use Aer simulator
sim = AerSimulator()
compiled_circuit = transpile(qc, sim)

# Run the job
job = sim.run(compiled_circuit, shots=1024)
result = job.result()

# Show measurement counts
counts = result.get_counts()
print("Counts:", counts)

# Plot histogram
plot_histogram(counts)

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator

# Define your circuit
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.measure_all()

# Initialize simulator backend
simulator = AerSimulator()

# Transpile the circuit for the backend
compiled_circuit = transpile(qc, simulator)

# Run the simulation
job = simulator.run(compiled_circuit, shots=1024)
result = job.result()
counts = result.get_counts()

# Display results
print("Compiled Circuit:")
print(compiled_circuit.draw())
print("Simulation Results:", counts)
